# %% [markdown]
# # Using qualdocs to process Google Docs comments

# %% [markdown]
# This assumes you have `client_secret.json` in your working directory per the instructions in README.md

# %% [markdown]
# ## Imports

# %%
# !pip install qualdocs
# Out:
# Requirement already satisfied: qualdocs in /opt/tljh/user/lib/python3.6/site-packages (0.0.8)
# Requirement already satisfied: google-api-python-client in /opt/tljh/user/lib/python3.6/site-packages (from qualdocs) (1.7.8)
# Requirement already satisfied: httplib2 in /opt/tljh/user/lib/python3.6/site-packages (from qualdocs) (0.12.1)
# Requirement already satisfied: PyDrive in /opt/tljh/user/lib/python3.6/site-packages (from qualdocs) (1.3.1)
# Requirement already satisfied: apiclient in /opt/tljh/user/lib/python3.6/site-packages (from qualdocs) (1.0.4)
# Requirement already satisfied: oauth2client in /opt/tljh/user/lib/python3.6/site-packages (from qualdocs) (4.1.3)
# Requirement already satisfied: numpy in /opt/tljh/user/lib/python3.6/site-packages (from qualdocs) (1.15.2)
# Requirement already satisfied: pandas in /opt/tljh/user/lib/python3.6/site-packages (from qualdocs) (0.23.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /opt/tljh/user/lib/python3.6/site-packages (from google-api-python-client->qualdocs) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /opt/tljh/user/lib/python3.6/site-packages (from google-api-python-client->qualdocs) (3.0.0)
# Requirement already satisfied: google-auth>=1.4.1 in /opt/tljh/user/lib/python3.6/site-packages (from google-api-python-client->qualdocs) (1.6.3)
# Requirement already satisfied: six<2dev,>=1.6.1 in /opt/tljh/user/lib/python3.6/site-packages (from google-api-python-client->qualdocs) (1.11.0)
# Requirement already satisfied: PyYAML>=3.0 in /opt/tljh/user/lib/python3.6/site-packages (from PyDrive->qualdocs) (3.13)
# Requirement already satisfied: certifi in /opt/tljh/user/lib/python3.6/site-packages (from apiclient->qualdocs) (2019.3.9)
# Requirement already satisfied: urllib3 in /opt/tljh/user/lib/python3.6/site-packages (from apiclient->qualdocs) (1.23)
# Requirement already satisfied: rsa>=3.1.4 in /opt/tljh/user/lib/python3.6/site-packages (from oauth2client->qualdocs) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /opt/tljh/user/lib/python3.6/site-packages (from oauth2client->qualdocs) (0.2.4)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/tljh/user/lib/python3.6/site-packages (from oauth2client->qualdocs) (0.4.5)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/tljh/user/lib/python3.6/site-packages (from pandas->qualdocs) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /opt/tljh/user/lib/python3.6/site-packages (from pandas->qualdocs) (2018.5)
# Requirement already satisfied: cachetools>=2.0.0 in /opt/tljh/user/lib/python3.6/site-packages (from google-auth>=1.4.1->google-api-python-client->qualdocs) (3.1.0)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
import qualdocs

# %% [markdown]
# ## Authentication
#
# Authenticate with get_credentials(), which gives you a link to open. Do the authentication dance, and it will give you a string to copy and paste into a box in the output window below. If you have trouble on Google's end, restart the notebook and use private/incognito mode. Sometimes it can take a couple tries. It stores credentials to a .json file in `~/.credentials/`. Close the window and come back when authentication is complete.

# %%
credentials = qualdocs.get_credentials()
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=TRUNCATED_FOR_PRIVACY
#
# Enter verification code: RANDOM_LETTERS_AND_NUMBERS
# Authentication successful.
# Storing credentials to /home/staeiou/.credentials/drive-api-qualdocs.json

# %%
service = qualdocs.get_service()

# %% [markdown]
# ## Search for files to process

# %%
ids = qualdocs.get_file_ids(service, search="lorem")
ids
# Out:
# {'qualdocs-test lorem': '1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI',
#  'qualdocs test lorem 2': '1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk'}

# %% [markdown]
# ## Query and parse into pandas dataframe

# %%
json_dict = qualdocs.get_json_dict(service, ids)

# %%
df = qualdocs.json_to_df(json_dict,ids)
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        text  \
# code     subcode   sub_subcode  name
# topcode1                        qualdocs test lorem 2  Sed convallis purus lorem, ut euismod lorem scelerisque at. Vestibulum est diam, convallis ac dictum id, sodales nec nisl. Maecenas malesuada neque vel enim vestibulum laoreet.
#           subcode1              qualdocs-test lorem    Nunc lacinia luctus mauris, vel malesuada lacus fermentum ullamcorper. Proin lacinia odio non tincidunt finibus.
#                                 qualdocs-test lorem    Vestibulum ac felis eget nisi iaculis condimentum. Morbi eros ligula, posuere id enim eu, dictum scelerisque magna.
#           subcode2              qualdocs test lorem 2  Vestibulum ac felis eget nisi iaculis condimentum.
#                                 qualdocs-test lorem    Lorem ipsum dolor sit amet, consectetur adipiscing elit. In enim sapien, fringilla vel sodales sed, tincidunt ut odio. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas.
#                                 qualdocs-test lorem    Duis a erat sodales, laoreet est vel, consequat libero. Donec nisl erat, venenatis sit amet lacinia sit amet, finibus in nulla.
#                                 qualdocs-test lorem    Nunc lacinia luctus mauris, vel malesuada lacus fermentum ullamcorper. Proin lacinia odio non tincidunt finibus.
#           subcode3              qualdocs test lorem 2  Vestibulum ac felis eget nisi iaculis condimentum.
#                                 qualdocs test lorem 2  Lorem ipsum dolor sit amet
#           subcode4              qualdocs test lorem 2  Lorem ipsum dolor sit amet
#                                 qualdocs-test lorem    Etiam ultrices sed risus id fermentum. Etiam placerat, mi id ultricies accumsan, arcu erat ornare tortor, sed gravida nisi eros eget ligula. Quisque sed libero pellentesque lorem varius egestas. Nam facilisis lacinia consequat. Aliquam porttitor ipsum non eros blandit commodo. Donec at elit ac sapien pellentesque accumsan. Nam hendrerit eget leo eget gravida. Fusce et dui luctus, malesuada elit sed, interdum nulla. Praesent ac venenatis mi. Maecenas suscipit metus in ipsum molestie, et elementum tortor mattis. Aenean at mattis lorem. Aenean at lacinia quam.
# topcode2                        qualdocs test lorem 2  Lorem ipsum dolor sit amet, consectetur adipiscing elit. In enim sapien, fringilla vel sodales sed, tincidunt ut odio. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Curabitur et nunc augue. Vestibulum ac felis eget nisi iaculis condimentum. Morbi eros ligula, posuere id enim eu, dictum scelerisque magna. Ut aliquam turpis ac ex tincidunt, suscipit viverra magna sagittis. Sed convallis purus lorem, ut euismod lorem scelerisque at. Vestibulum est diam, convallis ac dictum id, sodales nec nisl. Maecenas malesuada neque vel enim vestibulum laoreet. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas.
#                                 qualdocs-test lorem    Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas.
#           subcode1              qualdocs test lorem 2  Praesent id dui eu nulla volutpat laoreet. Nunc quis leo rhoncus, maximus sapien nec, rhoncus purus.
#                                 qualdocs test lorem 2  Nunc lacinia luctus mauris, vel malesuada lacus fermentum ullamcorper. Proin lacinia odio non tincidunt finibus.
#           subcode2  subsubcode1 qualdocs-test lorem    Praesent id dui eu nulla volutpat laoreet. Nunc quis leo rhoncus, maximus sapien nec, rhoncus purus. Mauris id commodo dolor. Morbi cursus velit massa, in lobortis urna laoreet non.
#           subcode3              qualdocs test lorem 2  Nam dapibus magna eget tortor porta, sed ultrices enim bibendum. Aliquam auctor dictum eleifend.
#                     subsubcode1 qualdocs-test lorem    Nulla arcu lectus, ornare interdum facilisis at, dignissim vitae nulla. Sed gravida lorem quam, id dapibus arcu ornare tristique.
#                     subsubcode3 qualdocs-test lorem    Nam dignissim urna nec elit sodales, non convallis magna pharetra. Praesent ac consequat lacus. Sed sit amet condimentum nisl.
#                     subsubcode4 qualdocs-test lorem    Nam dignissim urna nec elit sodales, non convallis magna pharetra. Praesent ac consequat lacus. Sed sit amet condimentum nisl.
#           subcode4              qualdocs test lorem 2  Lorem ipsum dolor sit amet
#                                 qualdocs test lorem 2  Nam dapibus magna eget tortor porta, sed ultrices enim bibendum. Aliquam auctor dictum eleifend.
# topcode3                        qualdocs test lorem 2  Etiam ultrices sed risus id fermentum. Etiam placerat, mi id ultricies accumsan, arcu erat ornare tortor, sed gravida nisi eros eget ligula. Quisque sed libero pellentesque lorem varius egestas. Nam facilisis lacinia consequat.
#
#                                                         comment_id  \
# code     subcode   sub_subcode  name
# topcode1                        qualdocs test lorem 2  AAAAA-veBHo
#           subcode1              qualdocs-test lorem    AAAAA-y8kfE
#                                 qualdocs-test lorem    AAAAA-y8ke8
#           subcode2              qualdocs test lorem 2  AAAACP0KnYI
#                                 qualdocs-test lorem    AAAAA-rM2bI
#                                 qualdocs-test lorem    AAAAA-y8kfI
#                                 qualdocs-test lorem    AAAAA-y8kfE
#           subcode3              qualdocs test lorem 2  AAAACP0KnYI
#                                 qualdocs test lorem 2  AAAAA-veBH0
#           subcode4              qualdocs test lorem 2  AAAAA-veBH0
#                                 qualdocs-test lorem    AAAAA-y8kfU
# topcode2                        qualdocs test lorem 2  AAAAC17ykBY
#                                 qualdocs-test lorem    AAAAA-y8kfA
#           subcode1              qualdocs test lorem 2  AAAAA-veBH8
#                                 qualdocs test lorem 2  AAAAA-veBHs
#           subcode2  subsubcode1 qualdocs-test lorem    AAAAA-rM2bE
#           subcode3              qualdocs test lorem 2  AAAAA-veBHw
#                     subsubcode1 qualdocs-test lorem    AAAAA-y8kfM
#                     subsubcode3 qualdocs-test lorem    AAAAA-y8kfQ
#                     subsubcode4 qualdocs-test lorem    AAAAA-y8kfQ
#           subcode4              qualdocs test lorem 2  AAAAB5CX1Dw
#                                 qualdocs test lorem 2  AAAAA-veBHw
# topcode3                        qualdocs test lorem 2  AAAAA-veBH4
#
#                                                                  coder  \
# code     subcode   sub_subcode  name
# topcode1                        qualdocs test lorem 2  R.Stuart Geiger
#           subcode1              qualdocs-test lorem    R.Stuart Geiger
#                                 qualdocs-test lorem    R.Stuart Geiger
#           subcode2              qualdocs test lorem 2  James Knox
#                                 qualdocs-test lorem    R.Stuart Geiger
#                                 qualdocs-test lorem    R.Stuart Geiger
#                                 qualdocs-test lorem    R.Stuart Geiger
#           subcode3              qualdocs test lorem 2  James Knox
#                                 qualdocs test lorem 2  R.Stuart Geiger
#           subcode4              qualdocs test lorem 2  R.Stuart Geiger
#                                 qualdocs-test lorem    R.Stuart Geiger
# topcode2                        qualdocs test lorem 2  R.Stuart Geiger
#                                 qualdocs-test lorem    R.Stuart Geiger
#           subcode1              qualdocs test lorem 2  R.Stuart Geiger
#                                 qualdocs test lorem 2  R.Stuart Geiger
#           subcode2  subsubcode1 qualdocs-test lorem    R.Stuart Geiger
#           subcode3              qualdocs test lorem 2  R.Stuart Geiger
#                     subsubcode1 qualdocs-test lorem    R.Stuart Geiger
#                     subsubcode3 qualdocs-test lorem    R.Stuart Geiger
#                     subsubcode4 qualdocs-test lorem    R.Stuart Geiger
#           subcode4              qualdocs test lorem 2  Food Delivery
#                                 qualdocs test lorem 2  R.Stuart Geiger
# topcode3                        qualdocs test lorem 2  R.Stuart Geiger
#
#                                                                                                                                                           url
# code     subcode   sub_subcode  name
# topcode1                        qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBHo
#           subcode1              qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfE
#                                 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8ke8
#           subcode2              qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAACP0KnYI
#                                 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-rM2bI
#                                 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfI
#                                 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfE
#           subcode3              qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAACP0KnYI
#                                 qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBH0
#           subcode4              qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBH0
#                                 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfU
# topcode2                        qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAC17ykBY
#                                 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfA
#           subcode1              qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBH8
#                                 qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBHs
#           subcode2  subsubcode1 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-rM2bE
#           subcode3              qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBHw
#                     subsubcode1 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfM
#                     subsubcode3 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfQ
#                     subsubcode4 qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfQ
#           subcode4              qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAB5CX1Dw
#                                 qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBHw
# topcode3                        qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBH4

# %% [markdown]
# ## Processing
#
# Get list of codes

# %%
qualdocs.get_code_list(df)
# Out:
# ['topcode1',
#  'topcode1: subcode1',
#  'topcode1: subcode1',
#  'topcode1: subcode2',
#  'topcode1: subcode2',
#  'topcode1: subcode2',
#  'topcode1: subcode2',
#  'topcode1: subcode3',
#  'topcode1: subcode3',
#  'topcode1: subcode4',
#  'topcode1: subcode4',
#  'topcode2',
#  'topcode2',
#  'topcode2: subcode1',
#  'topcode2: subcode1',
#  'topcode2: subcode2: subsubcode1',
#  'topcode2: subcode3',
#  'topcode2: subcode3: subsubcode1',
#  'topcode2: subcode3: subsubcode3',
#  'topcode2: subcode3: subsubcode4',
#  'topcode2: subcode4',
#  'topcode2: subcode4',
#  'topcode3']

# %% [markdown]
# Get all top-level codes:

# %%
list(df.index.get_level_values(0).unique())
# Out:
# ['topcode1', 'topcode2', 'topcode3']

# %% [markdown]
# Get all subcodes:

# %%
list(df.index.get_level_values(1).unique())
# Out:
# ['', ' subcode1', ' subcode2', ' subcode3', ' subcode4']

# %% [markdown]
# Get all sub-subcodes:

# %%
list(df.index.get_level_values(2).unique())
# Out:
# ['', ' subsubcode1', ' subsubcode3', ' subsubcode4']

# %% [markdown]
# ## Counts by code
# ### Ordered by index

# %%
df_counts = pd.DataFrame(df.groupby(level=[0, 1, 2]).count()['comment_id'])
df_counts.columns = ['count']
df_counts
# Out:
#                                  count
# code     subcode   sub_subcode
# topcode1                         1
#           subcode1               2
#           subcode2               4
#           subcode3               2
#           subcode4               2
# topcode2                         2
#           subcode1               2
#           subcode2  subsubcode1  1
#           subcode3               1
#                     subsubcode1  1
#                     subsubcode3  1
#                     subsubcode4  1
#           subcode4               2
# topcode3                         1

# %% [markdown]
# ### Ordered by count

# %%
df_counts.sort_values(by='count', ascending=False)
# Out:
#                                  count
# code     subcode   sub_subcode
# topcode1  subcode2               4
#           subcode1               2
#           subcode3               2
#           subcode4               2
# topcode2                         2
#           subcode1               2
#           subcode4               2
# topcode1                         1
# topcode2  subcode2  subsubcode1  1
#           subcode3               1
#                     subsubcode1  1
#                     subsubcode3  1
#                     subsubcode4  1
# topcode3                         1

# %% [markdown]
# ## Filtering and searching
# ### Filter by a top-level code:

# %%
df.xs('topcode1', level='code', drop_level=False)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      text  \
# code     subcode   sub_subcode name
# topcode1                       qualdocs test lorem 2  Sed convallis purus lorem, ut euismod lorem scelerisque at. Vestibulum est diam, convallis ac dictum id, sodales nec nisl. Maecenas malesuada neque vel enim vestibulum laoreet.
#           subcode1             qualdocs-test lorem    Nunc lacinia luctus mauris, vel malesuada lacus fermentum ullamcorper. Proin lacinia odio non tincidunt finibus.
#                                qualdocs-test lorem    Vestibulum ac felis eget nisi iaculis condimentum. Morbi eros ligula, posuere id enim eu, dictum scelerisque magna.
#           subcode2             qualdocs test lorem 2  Vestibulum ac felis eget nisi iaculis condimentum.
#                                qualdocs-test lorem    Lorem ipsum dolor sit amet, consectetur adipiscing elit. In enim sapien, fringilla vel sodales sed, tincidunt ut odio. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas.
#                                qualdocs-test lorem    Duis a erat sodales, laoreet est vel, consequat libero. Donec nisl erat, venenatis sit amet lacinia sit amet, finibus in nulla.
#                                qualdocs-test lorem    Nunc lacinia luctus mauris, vel malesuada lacus fermentum ullamcorper. Proin lacinia odio non tincidunt finibus.
#           subcode3             qualdocs test lorem 2  Vestibulum ac felis eget nisi iaculis condimentum.
#                                qualdocs test lorem 2  Lorem ipsum dolor sit amet
#           subcode4             qualdocs test lorem 2  Lorem ipsum dolor sit amet
#                                qualdocs-test lorem    Etiam ultrices sed risus id fermentum. Etiam placerat, mi id ultricies accumsan, arcu erat ornare tortor, sed gravida nisi eros eget ligula. Quisque sed libero pellentesque lorem varius egestas. Nam facilisis lacinia consequat. Aliquam porttitor ipsum non eros blandit commodo. Donec at elit ac sapien pellentesque accumsan. Nam hendrerit eget leo eget gravida. Fusce et dui luctus, malesuada elit sed, interdum nulla. Praesent ac venenatis mi. Maecenas suscipit metus in ipsum molestie, et elementum tortor mattis. Aenean at mattis lorem. Aenean at lacinia quam.
#
#                                                        comment_id  \
# code     subcode   sub_subcode name
# topcode1                       qualdocs test lorem 2  AAAAA-veBHo
#           subcode1             qualdocs-test lorem    AAAAA-y8kfE
#                                qualdocs-test lorem    AAAAA-y8ke8
#           subcode2             qualdocs test lorem 2  AAAACP0KnYI
#                                qualdocs-test lorem    AAAAA-rM2bI
#                                qualdocs-test lorem    AAAAA-y8kfI
#                                qualdocs-test lorem    AAAAA-y8kfE
#           subcode3             qualdocs test lorem 2  AAAACP0KnYI
#                                qualdocs test lorem 2  AAAAA-veBH0
#           subcode4             qualdocs test lorem 2  AAAAA-veBH0
#                                qualdocs-test lorem    AAAAA-y8kfU
#
#                                                                 coder  \
# code     subcode   sub_subcode name
# topcode1                       qualdocs test lorem 2  R.Stuart Geiger
#           subcode1             qualdocs-test lorem    R.Stuart Geiger
#                                qualdocs-test lorem    R.Stuart Geiger
#           subcode2             qualdocs test lorem 2  James Knox
#                                qualdocs-test lorem    R.Stuart Geiger
#                                qualdocs-test lorem    R.Stuart Geiger
#                                qualdocs-test lorem    R.Stuart Geiger
#           subcode3             qualdocs test lorem 2  James Knox
#                                qualdocs test lorem 2  R.Stuart Geiger
#           subcode4             qualdocs test lorem 2  R.Stuart Geiger
#                                qualdocs-test lorem    R.Stuart Geiger
#
#                                                                                                                                                          url
# code     subcode   sub_subcode name
# topcode1                       qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBHo
#           subcode1             qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfE
#                                qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8ke8
#           subcode2             qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAACP0KnYI
#                                qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-rM2bI
#                                qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfI
#                                qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfE
#           subcode3             qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAACP0KnYI
#                                qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBH0
#           subcode4             qualdocs test lorem 2  https://docs.google.com/document/d/1guJL7obwENn5GYOZarifxk3xPvWrk6NJ7WEfXQHTkBk/edit?disco=AAAAA-veBH0
#                                qualdocs-test lorem    https://docs.google.com/document/d/1EtYEx9U9KRfAOAh9LaSsmIQyDqiJ392qZJom1Jmv5MI/edit?disco=AAAAA-y8kfU
